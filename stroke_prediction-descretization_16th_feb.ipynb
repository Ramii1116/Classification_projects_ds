# %% [markdown]
# # **Discretization**

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("stroke_prediction.csv")
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df["hypertension"].replace({ 0 :"No",1 : "Yes"},inplace=True)
df
# Out:
#           id  gender   age hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0           No              0           No
# 1      30468    Male  58.0          Yes              0          Yes
# 2      16523  Female   8.0           No              0           No
# 3      56543  Female  70.0           No              0          Yes
# 4      46136    Male  14.0           No              0           No
# ...      ...     ...   ...          ...            ...          ...
# 43395  56196  Female  10.0           No              0           No
# 43396   5450  Female  56.0           No              0          Yes
# 43397  28375  Female  82.0          Yes              0          Yes
# 43398  27973    Male  40.0           No              0          Yes
# 43399  36271  Female  82.0           No              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  object
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 4.0+ MB

# %%
df.groupby("stroke")["avg_glucose_level"].mean()
# Out:
# stroke
# 0    104.021590
# 1    129.582669
# Name: avg_glucose_level, dtype: float64

# %%
df.groupby("stroke")["avg_glucose_level"].describe()
# Out:
#           count        mean        std    min    25%     50%     75%     max
# stroke
# 0       42617.0  104.021590  42.608788  55.00  77.50   91.47  111.67  291.05
# 1         783.0  129.582669  59.734073  55.01  80.99  104.47  192.36  271.74

# %%
df.groupby("stroke")["age"].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# stroke
# 0       42617.0  41.741565  22.385094  0.08  24.0  43.0  59.0  82.0
# 1         783.0  68.143448  12.316537  1.32  60.0  71.0  79.0  82.0

# %%
childrens = df[(df["age"]>=0) & (df["age"]<12)]
childrens
# Out:
#           id  gender    age hypertension  heart_disease ever_married  \
# 0      30669    Male   3.00           No              0           No
# 2      16523  Female   8.00           No              0           No
# 33     33759  Female   3.00           No              0           No
# 42     11014    Male   4.00           No              0           No
# 73     39038    Male  11.00           No              0           No
# ...      ...     ...    ...          ...            ...          ...
# 43369  62703    Male   1.72           No              0           No
# 43376  65913  Female   3.00           No              0           No
# 43382  35179  Female   9.00           No              0           No
# 43391  30077    Male   6.00           No              0           No
# 43395  56196  Female  10.00           No              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi smoking_status  stroke
# ...

# %%
childrens["stroke"].value_counts() 
# df lo column laane childrens lo column ni access chesam
# so children ki stroke problems raavatledhu fix
# Out:
# stroke
# 0    4927
# 1       1
# Name: count, dtype: int64

# %%
df["age_category"] = pd.cut(df["age"],
                           bins = [0,12,19,30,40,60,90],
                           labels = ["childs","teens","youngs","middles","seniors","oldage"])

# %%
df[["age","age_category"]]
# Out:
#         age age_category
# 0       3.0       childs
# 1      58.0      middles
# 2       8.0       childs
# 3      70.0      seniors
# 4      14.0        teens
# ...     ...          ...
# 43395  10.0       childs
# 43396  56.0      middles
# 43397  82.0      seniors
# 43398  40.0      middles
# 43399  82.0      seniors
#
# [43400 rows x 2 columns]

# %%
pd.crosstab(df["age_category"],df["stroke"],margins = True)
# Out:
# stroke            0    1    All
# age_category
# childs         5325    1   5326
# teens          3184    1   3185
# youngs         5723    2   5725
# middles       18453  200  18653
# seniors        9932  579  10511
# All           42617  783  43400

# %% [markdown]
# # **Next project....ENCODINGS**

# %% [markdown]
# - # 1st method

# %%
df = pd.DataFrame({"Shirt_Size" : ["xl","small","medium","large"]})
df
# Out:
#   Shirt_Size
# 0         xl
# 1      small
# 2     medium
# 3      large

# %% [markdown]
# # - 2nd Method

# %%
list_of_tuples = [("Shirt_Size" ,"xl","small","medium","large")] # rows wise creating
df = pd.DataFrame(list_of_tuples)
df
# Out:
#             0   1      2       3      4
# 0  Shirt_Size  xl  small  medium  large

# %%
list_of_tuples = [("Shirt_Size" ),("xl","small","medium","large")]
df = pd.DataFrame(list_of_tuples)
df
# Out:
#                             0
# 0                  Shirt_Size
# 1  (xl, small, medium, large)

# %%
list_of_tuples = [("Shirt_Size" ),("xl"),("small"),("medium"),("large")]
df = pd.DataFrame(list_of_tuples)
df
# Out:
#             0
# 0  Shirt_Size
# 1          xl
# 2       small
# 3      medium
# 4       large

# %%
list_of_tuples = [("Shirt_Size",'s','m','l' ),("xl",1,2,3),("small",4,5,6),("medium",7,8,9),("large",10,11,12)]
df = pd.DataFrame(list_of_tuples)
df
# Out:
#             0   1   2   3
# 0  Shirt_Size   s   m   l
# 1          xl   1   2   3
# 2       small   4   5   6
# 3      medium   7   8   9
# 4       large  10  11  12

# %% [markdown]
# # 3rd method is read csv...we knew it right

# %%
df1 = pd.DataFrame({"Shirt_Size" : ["xl","small","medium","large"]}) # coloumns wise creating
df
# Out:
#             0   1   2   3
# 0  Shirt_Size   s   m   l
# 1          xl   1   2   3
# 2       small   4   5   6
# 3      medium   7   8   9
# 4       large  10  11  12

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories =[["small","medium","large","xl"]])
# should be ascending order it assings the first value as the 0 and so on

df1["oe_shirt_size"] = oe.fit_transform(df1[["Shirt_Size"]]).astype("int")
df1
# Out:
#   Shirt_Size  oe_shirt_size
# 0         xl              3
# 1      small              0
# 2     medium              1
# 3      large              2

# %%
df1 = pd.DataFrame({"Shirt_Size" : ["xl","small","medium","large"]}) # coloumns wise creating

df1["map_shirts"] = df1["Shirt_Size"].map({"small":0,"medium":1,"large":2,"xl":3})
df1
# Out:
#   Shirt_Size  map_shirts
# 0         xl           3
# 1      small           0
# 2     medium           1
# 3      large           2
